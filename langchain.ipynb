# %% [markdown]
# <a href="https://colab.research.google.com/github/KishoreKumar477/lang_chain/blob/main/langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %time
from langchain_google_genai import ChatGoogleGenerativeAI
import os
from google.colab import userdata


os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)
while True:
  response= input('prompt here (press enter to end):')
  if response !='':
    response = llm.invoke(response)
    print(response.content)
  else:
    break
# %time
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.53 µs
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# prompt here (press enter to end):explain about langchain in laymans term
# Imagine you have a **super-smart brain** (that's your Large Language Model, or LLM, like ChatGPT). This brain is amazing at understanding language, writing, and coming up with ideas. But it has a few limitations:
#
# 1.  **It only knows what it was trained on.** It can't browse the live internet for today's news or look up specific facts in a private document.
# 2.  **It has a terrible short-term memory.** It forgets what you said five minutes ago in a long conversation.
# 3.  **It struggles with multi-step tasks.** If you ask it to "plan a trip to Rome, check flight prices, and then book a hotel," it might just give you a generic essay about Rome, not actually *do* those things.
# ...

# %%
readme_prompt = """Generate a comprehensive README.md file for a Python project hosted in Google Colab. The project uses the `langchain_google_genai` library to interact with a Gemini LLM. It includes:1. An initial setup cell to install `langchain-google-genai` and configure the `GEMINI_API_KEY` using `google.colab.userdata.get()`. It should also include instructions on how to add the API key to Colab Secrets.2. An interactive loop where the user can input prompts and the LLM provides responses.3. A separate code snippet to generate file names based on user input, also using the LLM.The README should cover: - Project Title - A brief description of the project - Setup instructions (including API key management) - How to run the interactive LLM chat - How to use the file name generator - Any necessary dependencies and installation steps.Make sure to format it with Markdown headings and code blocks where appropriate."""

readme_content = llm.invoke(readme_prompt).content

with open('README.md', 'w') as f:
    f.write(readme_content)

print("README.md has been generated and saved.")
print(readme_content)
# Out:
# README.md has been generated and saved.
# Here's a comprehensive `README.md` file for your Python project hosted in Google Colab, leveraging `langchain_google_genai` with Gemini LLM.
#
# ---
#
# # Colab Gemini LLM Toolkit: Chat & File Name Generator
#
# ## Project Title
#
# **Colab Gemini LLM Toolkit: Interactive Chat & Smart File Name Generator**
#
# ## Brief Description
#
# This Google Colab notebook provides a convenient and interactive environment to experiment with Google's Gemini Large Language Model (LLM) using the `langchain_google_genai` library. It features two core functionalities:
#
# 1.  **Interactive Chatbot:** Engage in a real-time conversation with the Gemini LLM, inputting prompts and receiving immediate responses.
# 2.  **Smart File Name Generator:** Provide a topic, and the LLM will intelligently suggest multiple, descriptive, and valid file names, complete with appropriate extensions.
#
# ...
